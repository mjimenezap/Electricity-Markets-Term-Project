# %%
import numpy as np 
import pandas as pd
import itertools
from scipy.optimize import linprog

# %%
#Read the data with the load profile and proces for each hour
data = pd.read_csv('load_price_business_working_hours.csv')
data.drop(columns=['Unnamed: 0'])

##Variables for sensitivity analysis

# #Size of the storage
# num_vehicles = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200]

# #Battery specifications
# charger_power = [0.006, 0.0072, 0.0008] #MW
# energy_vehicle = [0.040, 0.064, 0.080] #MWh
# eff = [0.9, 0.95, 0.97] #eficiency 
# avg_initial_energy = [0.6, 0.7, 0.8]


#Size of the storage
num_vehicles = [20, 60, 100, 140, 180, 200]

#Battery specifications
charger_power = [0.0072, 0.0008] #MW
energy_vehicle = [0.040, 0.064, 0.080] #MWh
eff = [0.9, 0.95, 0.97] #eficiency 
avg_initial_energy = [0.7, 0.8]



# num_vehicles = [30]
# charger_power = [0.0072]
# energy_vehicle = [0.064]
# eff = [0.99]
# avg_initial_energy = [0.7]

# %%
# https://www.geeksforgeeks.org/python-creating-3d-list/
 
def ThreeD(a, b, c): 
    lst = [[ ['0' for col in range(a)] for col in range(b)] for row in range(c)] 

    return lst

# %%
def sensitivity_analysis(num_vehicles, charger_power, energy_vehicle, eff, avg_initial_energy,data):
    
    
    ##Storage specifications

    #Power of storage charge/discharge
    Psc_max = charger_power #MW
    Pdc_max = charger_power #MW

    #Maximum/minimum avaliable energy in the storage system
    Es_max = energy_vehicle #MW
    Es_min = 0.25*energy_vehicle #MW

    #Initial storage
    Initial_battery_vec = np.random.normal(avg_initial_energy,0.1,num_vehicles) 
    
    Initial_E_vec = Initial_battery_vec*energy_vehicle #MWh
       
    ##Optimization

    max_demand = 100/1000 #Max demand is assumed to be 0.1 MW (medium business)
    
    #Arrays for the results
    
    Px = ThreeD(len(data), 1, num_vehicles)
    Pchar = ThreeD(len(data), 1, num_vehicles)
    Pdis = ThreeD(len(data), 1, num_vehicles)
    E= ThreeD(len(data), 1, num_vehicles)
    original_cost = [ ];
    savings = ThreeD(int(len(data)/10), 1, num_vehicles) 
    
    
    for b in range(len(Initial_E_vec)): 
        
        for d in range(int(len(data)/10)): 
            
            Pd = data['Hourly Load'][d*10:(d+1)*10]/1000; #Demand vector in MWh
            
            print(b)
            
            n = len(Pd)  #Number of hours
            
            # vector x: Px(1 - n) | Pchar(n+1 - 2n) | Pdis(2n+1 - 3n) | Energy(3n+1 - 4n) | E0(4n+1)|
            # Where:
            #   - Px is the exchange with the grid 
            #   - Pchar is the Energy Storage charge
            #   - Pdis is the Energy Storage discharge

            f1 = data['Hourly Price'][d*10:(d+1)*10]*1000 #prices in $/MWh (original in $/kWh)

            f23 = list(np.zeros(2*n))
            f4 = list(np.zeros(n))

            f = []  #cost vector

            f.append(f1)
            f.append(f23)
            f.append(f4)

            f = list(itertools.chain(*f)) #flatten the vector 
            f.append(0.0)
            
            # Building Aeq Matrix
            # n rows for power balances equations 
            # n rows for energy balances equations
            # 2 rows for setting the initial energy in the storage and final energy
            # equal to initial 
            
            Aeq = np.zeros((2*n+2,4*n+1))
            #indices for submatrices
            sP = 0
            sC = n
            sD = 2*n
            sE = 3*n 
            
            for i in range(n): 
                Aeq[i,i]=1
                Aeq[i,i+sC]=-1
                Aeq[i,i+sD]=1
                
                r = n+i
                Aeq[r,i+sC]=-eff
                Aeq[r,i+sD]=1/eff
                Aeq[r,i+sE]=1
                Aeq[r,i+sE-1]=-1
            
            
            Aeq[n,sE-1]=0
            Aeq[n,4*n]=-1
            Aeq[2*n,4*n]=1
            Aeq[2*n+1,4*n-1]=1
            Aeq[2*n+1,4*n]=-1

            
            #Building Beq Matrix

            beq = []

            beq.append(list(Pd))
            beq.append(list(np.zeros(n+2)))

            beq = list(itertools.chain(*beq)) #flatten the vector 
            
            beq[2*n] = Initial_E_vec[b-1]
            
                        
            # Lower bounds 
            # The minimum exchange with the grid is when there is no demand and the
            # storage system is discharging at maximum rate
            # The minimum charge and discharge power is zero 
            
            lb_vec = []
            lb_vec.append(list(-1*Pdc_max*np.ones(n)))
            lb_vec.append(np.zeros(n))
            lb_vec.append(np.zeros(n))
            lb_vec.append(Es_min*np.ones(n))
            lb_vec = list(itertools.chain(*lb_vec))
            lb_vec.append(0.0)                     
            
            
            # Upper bounds 
            # The maximum exchange with the grid is when there is the maximum demand and the
            # storage system is charging at maximum rate
            # The maximum charge and discharge power are specified in the previous section 

            ub_vec = []
            ub_vec.append(list(Psc_max*np.ones(n)+max_demand))
            ub_vec.append(Psc_max*np.ones(n))
            ub_vec.append(Pdc_max*np.ones(n))
            ub_vec.append(Es_max*np.ones(n))
            ub_vec = list(itertools.chain(*ub_vec))
            ub_vec.append(999)  
            
            bounds = []

            for i in range(len(lb_vec)): 
                bounds.append((lb_vec[i],ub_vec[i]))           

            res = linprog(f, A_eq=Aeq, b_eq=beq, bounds=bounds, options={"disp": True})
 
            original_cost_aux = original_cost
            
            pos_x = 0
            for c in range(d*10,(d+1)*10):
                Px[b][0][c] = res.x[pos_x]
                Pchar[b][0][c] = res.x[n+pos_x]
                Pdis[b][0][c] = res.x[2*n+pos_x]
                E[b][0][c]= res.x[3*n+pos_x]
                
                pos_x = pos_x+1

            Pdis_curr_iter = res.x[2*n:3*n]
            Pchar_curr_iter = res.x[n:2*n]

            #The original cost just need to be calculated once, 
            #so it is going to be calculated for the first vehicle
            
            if b == 0: 
                original_cost.append(sum(Pd*f1))

            #The reduction associated to the storage must be calculated for each
            #vehicle, as each one is considered as an independent storage
            savings[b][0][d]= [sum(Pdis_curr_iter*f1) - sum(Pchar_curr_iter*f1)] 

            
    ##Economic analysis

    aggregated_savings= np.zeros(int(len(data)/10));

    for d in range(int(len(data)/10)):
        agg_svg_day = 0
        for b in range(len(Initial_E_vec)):
            agg_svg_aux =  agg_svg_day
            agg_svg_day = agg_svg_aux + float(savings[b][0][d][0])

        aggregated_savings[d] = agg_svg_day

    total_original_cost = sum(original_cost)
    total_savings = sum(aggregated_savings)

    return total_savings, total_original_cost

# %%
# [total_savings,total_original_cost] = sensitivity_analysis(30, 0.0072, 0.064, 0.99, 0.7,data)

# %%
# print(total_savings)
# print(total_original_cost)

# %%
results = []

for n in num_vehicles: 
    for c in charger_power: 
        for e in energy_vehicle: 
            for ef in eff: 
                for i in avg_initial_energy: 
                    
                    [total_savings,total_original_cost] = sensitivity_analysis(n, c, e, ef, i,data)
                    
                    results.append([n, c, e, ef, i,total_savings,total_original_cost])
# Out:
# 0
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 1
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 1
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 1
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 1
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 1
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 1
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 1
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 2
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 3
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 3
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 3
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 3
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 3
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 3
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 3
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 4
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 89
# 4
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 89
# 4
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 89
# 4
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 89
# 4
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 89
# 4
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 89
# 4
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 89
# 5
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 86
# 6
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 6
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 6
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 6
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 6
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 6
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 6
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 7
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 9
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 10
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 87
# 11
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 11
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 11
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 11
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 11
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 11
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 11
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 12
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 89
# 13
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 89
# 13
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 89
# 13
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 89
# 13
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 89
# 13
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 89
# 13
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 89
# 14
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 14
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 14
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 14
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 14
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 14
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 14
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 15
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 15
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 15
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 15
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 15
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 15
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 15
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 16
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 87
# 16
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 87
# 16
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 87
# 16
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 87
# 16
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 87
# 16
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 87
# 16
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 87
# 17
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 19
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 19
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 19
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 19
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 19
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 19
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 19
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 0
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 87
# 2
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 87
# 2
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 87
# 2
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 87
# 2
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 87
# 2
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 87
# 2
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 87
# 3
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 85
# 3
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 85
# 3
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 85
# 3
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 85
# 3
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 85
# 3
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 85
# 3
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 85
# 4
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 86
# 4
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 86
# 4
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 86
# 4
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 86
# 4
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 86
# 4
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 86
# 4
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 86
# 5
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 86
# 6
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 85
# 6
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 85
# 6
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 85
# 6
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 85
# 6
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 85
# 6
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 85
# 6
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 85
# 7
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 7
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 8
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 85
# 8
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 85
# 8
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 85
# 8
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 85
# 8
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 85
# 8
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 85
# 8
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 85
# 9
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 87
# 9
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 87
# 9
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 87
# 9
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 87
# 9
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 87
# 9
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 87
# 9
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 87
# 10
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 94
# 10
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 94
# 10
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 94
# 10
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 94
# 10
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 94
# 10
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 94
# 10
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 94
# 11
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 12
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 91
# 13
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 91
# 13
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 91
# 13
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 91
# 13
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 91
# 13
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 91
# 13
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 91
# 14
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 86
# 14
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 86
# 14
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 86
# 14
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 86
# 14
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 86
# 14
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 86
# 14
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 86
# 15
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 92
# 17
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 92
# 18
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 89
# 19
# Optimization terminated successfully.
#          Current function value: 38.461052
#          Iterations: 82
# 19
# Optimization terminated successfully.
#          Current function value: 38.330888
#          Iterations: 82
# 19
# Optimization terminated successfully.
#          Current function value: 38.271387
#          Iterations: 82
# 19
# Optimization terminated successfully.
#          Current function value: 38.389299
#          Iterations: 82
# 19
# Optimization terminated successfully.
#          Current function value: 38.402768
#          Iterations: 82
# 19
# Optimization terminated successfully.
#          Current function value: 38.241231
#          Iterations: 82
# 19
# Optimization terminated successfully.
#          Current function value: 38.569993
#          Iterations: 82
# 0
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 1
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 2
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 3
# Optimization terminated successfully.
#          Current function value: 38.454376
#          Iterations: 93
# 3
# Optimization terminated successfully.
#          Current function value: 38.324212
#          Iterations: 93
# 3
# Optimization terminated successfully.
#          Current function value: 38.264711
#          Iterations: 93
# 3
# Optimization terminated successfully.
#          Current function value: 38.382622
#          Iterations: 93
# 3
# Optimization terminated successfully.
#          Current function value: 38.396092
#          Iterations: 93
# 3
# Optimization terminated successfully.
#          Current function value: 38.234554
#          Iterations: 93
# 3
# Optimization terminated successfully.
#          Current function value: 38.563317
#          Iterations: 93
# 4
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 4
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 4
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 4
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 4
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 4
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 4
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 5
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 6
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 89
# 6
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 89
# 6
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 89
# 6
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 89
# 6
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 89
# 6
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 89
# 6
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 89
# 7
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 7
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 7
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 7
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 7
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 7
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 7
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 8
# Optimization terminated successfully.
#          Current function value: 38.455955
#          Iterations: 91
# 8
# Optimization terminated successfully.
#          Current function value: 38.325790
#          Iterations: 91
# 8
# Optimization terminated successfully.
#          Current function value: 38.266290
#          Iterations: 91
# 8
# Optimization terminated successfully.
#          Current function value: 38.384201
#          Iterations: 91
# 8
# Optimization terminated successfully.
#          Current function value: 38.397671
#          Iterations: 91
# 8
# Optimization terminated successfully.
#          Current function value: 38.236133
#          Iterations: 91
# 8
# Optimization terminated successfully.
#          Current function value: 38.564896
#          Iterations: 91
# 9
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 89
# 9
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 89
# 9
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 89
# 9
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 89
# 9
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 89
# 9
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 89
# 9
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 89
# 10
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 89
# 11
# Optimization terminated successfully.
#          Current function value: 38.454988
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.324824
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.265323
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.383235
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.396704
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.235167
#          Iterations: 92
# 11
# Optimization terminated successfully.
#          Current function value: 38.563929
#          Iterations: 92
# 12
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 12
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 13
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 14
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 15
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 89
# 15
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 89
# 16
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 16
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 16
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 16
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 16
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 16
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 16
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 17
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 89
# 17
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 89
# 18
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 18
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 18
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 18
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 18
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 18
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 18
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.234400
#          Iterations: 90
# 19
# Optimization terminated successfully.
#          Current function value: 38.563162
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.454221
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.324057
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.264557
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.382468
#          Iterations: 90
# 0
# Optimization terminated successfully.
#          Current function value: 38.395938
#          Iterations: 90
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-90697f3c98da> in <module>
#       7                 for i in avg_initial_energy:
#       8
# ----> 9                     [total_savings,total_original_cost] = sensitivity_analysis(n, c, e, ef, i,data)
#      10
#      11                     results.append([n, c, e, ef, i,total_savings,total_original_cost])
#
# <ipython-input-4-ac264abe8144> in sensitivity_analysis(num_vehicles, charger_power, energy_vehicle, eff, avg_initial_energy, data)
#     137                 bounds.append((lb_vec[i],ub_vec[i]))
#     138
# --> 139             res = linprog(f, A_eq=Aeq, b_eq=beq, bounds=bounds, options={"disp": True})
#     140
#     141             original_cost_aux = original_cost
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/_linprog.py in linprog(c, A_ub, b_ub, A_eq, b_eq, bounds, method, callback, options)
#     464         if meth == 'simplex':
#     465             x, status, message, iteration = _linprog_simplex(
# --> 466                 c, c0=c0, A=A, b=b, callback=callback, _T_o=T_o, **solver_options)
#     467         elif meth == 'interior-point':
#     468             x, status, message, iteration = _linprog_ip(
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/_linprog_simplex.py in _linprog_simplex(c, c0, A, b, maxiter, disp, callback, tol, bland, _T_o, **unknown_options)
#     581
#     582     nit1, status = _solve_simplex(T, n, basis, phase=1, callback=callback,
# --> 583                                   maxiter=maxiter, tol=tol, bland=bland, _T_o=_T_o)
#     584     # if pseudo objective is zero, remove the last row from the tableau and
#     585     # proceed to phase 2
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/_linprog_simplex.py in _solve_simplex(T, n, basis, maxiter, phase, status, message, callback, tol, nit0, bland, _T_o)
#     357     while not complete:
#     358         # Find the pivot column
# --> 359         pivcol_found, pivcol = _pivot_col(T, tol, bland)
#     360         if not pivcol_found:
#     361             pivcol = np.nan
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/_linprog_simplex.py in _pivot_col(T, tol, bland)
#      65     if bland:
#      66         return True, np.nonzero(ma.mask == False)[0][0]
# ---> 67     return True, np.ma.nonzero(ma == ma.min())[0][0]
#      68
#      69
#
# KeyboardInterrupt:

# %%
results

# %%
df_results = pd.DataFrame(results, columns =['num_vehicles', 'charger_power','energy_vehicle','efficiency','avg_initial_energy','total_savings','total_original_cost']) 
df_results.to_csv('data.csv', index=False)

# %%
df_results.to_pickle("./results_97_light.pkl")
