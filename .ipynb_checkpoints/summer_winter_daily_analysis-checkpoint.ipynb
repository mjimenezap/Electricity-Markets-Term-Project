# %%
import numpy as np 
import pandas as pd
import itertools
from scipy.optimize import linprog

# %%
#Read the data with the load profile and proces for each hour
data = pd.read_csv('load_price_business_working_hours_winter_summer.csv')
data.drop(columns=['Unnamed: 0'])

num_work_hours = 10

##Variables for sensitivity analysis

# Size of the storage
num_vehicles = [100]

# Battery specifications
charger_power = [0.0072] #MW
energy_vehicle = [0.064] #MWh
eff = [0.97] #eficiency 
avg_initial_energy = [0.7]

# %%
len(data)/10
# Out:
# 181.0

# %%
len(data)/8
# Out:
# 226.25

# %%
# https://www.geeksforgeeks.org/python-creating-3d-list/
 
def ThreeD(a, b, c): 
    lst = [[ ['0' for col in range(a)] for col in range(b)] for row in range(c)] 

    return lst

# %%
def daily_analysis(num_vehicles, charger_power, energy_vehicle, eff, avg_initial_energy,data):
    
    
    ##Storage specifications

    #Power of storage charge/discharge
    Psc_max = charger_power #MW
    Pdc_max = charger_power #MW

    #Maximum/minimum avaliable energy in the storage system
    Es_max = energy_vehicle #MW
    Es_min = 0.25*energy_vehicle #MW

    #Initial storage
    Initial_battery_vec = np.random.normal(avg_initial_energy,0.1,num_vehicles) 
    
    Initial_E_vec = Initial_battery_vec*energy_vehicle #MWh
       
    ##Optimization

    max_demand = 100/1000 #Max demand is assumed to be 0.1 MW (medium business)
    
    #Arrays for the results
    
    Px = ThreeD(len(data), 1, num_vehicles)
    Pchar = ThreeD(len(data), 1, num_vehicles)
    Pdis = ThreeD(len(data), 1, num_vehicles)
    E = ThreeD(len(data), 1, num_vehicles)
    original_cost = [ ];
    savings = ThreeD(int(len(data)/num_work_hours), 1, num_vehicles) 
    
    
    for b in range(len(Initial_E_vec)): 
        
#         for d in range(int(len(data)/10)):  # For each day (which has 10 labor hours)
            
#             Pd = data['Hourly Load'][d*10:(d+1)*10]/1000; #Demand vector in MWh

        for d in range(int(len(data)/num_work_hours)):  # For each day (which has 10 labor hours)
            
            Pd = data['Hourly Load'][d*num_work_hours:(d+1)*num_work_hours]/1000; #Demand vector in MWh
            
            n = len(Pd)  #Number of hours
            
            # vector x: Px(1 - n) | Pchar(n+1 - 2n) | Pdis(2n+1 - 3n) | Energy(3n+1 - 4n) | E0(4n+1)|
            # Where:
            #   - Px is the exchange with the grid 
            #   - Pchar is the Energy Storage charge
            #   - Pdis is the Energy Storage discharge

            f1 = data['Hourly Price'][d*num_work_hours:(d+1)*num_work_hours]*1000 #prices in $/MWh (original in $/kWh)

            f23 = list(np.zeros(2*n))
            f4 = list(np.zeros(n))

            f = []  #cost vector

            f.append(f1)
            f.append(f23)
            f.append(f4)

            f = list(itertools.chain(*f)) #flatten the vector 
            f.append(0.0)
            
            # Building Aeq Matrix
            # n rows for power balances equations 
            # n rows for energy balances equations
            # 2 rows for setting the initial energy in the storage and final energy
            # equal to initial 
            
            Aeq = np.zeros((2*n+2,4*n+1))
            #indices for submatrices
            sP = 0
            sC = n
            sD = 2*n
            sE = 3*n 
            
            for i in range(n): 
                Aeq[i,i]=1
                Aeq[i,i+sC]=-1
                Aeq[i,i+sD]=1
                
                r = n+i
                Aeq[r,i+sC]=-eff
                Aeq[r,i+sD]=1/eff
                Aeq[r,i+sE]=1
                Aeq[r,i+sE-1]=-1
            
            
            Aeq[n,sE-1]=0
            Aeq[n,4*n]=-1
            Aeq[2*n,4*n]=1
            Aeq[2*n+1,4*n-1]=1
            Aeq[2*n+1,4*n]=-1

            
            #Building Beq Matrix

            beq = []

            beq.append(list(Pd))
            beq.append(list(np.zeros(n+2)))

            beq = list(itertools.chain(*beq)) #flatten the vector 
            
            beq[2*n] = Initial_E_vec[b-1]
            
                        
            # Lower bounds 
            # The minimum exchange with the grid is when there is no demand and the
            # storage system is discharging at maximum rate
            # The minimum charge and discharge power is zero 
            
            lb_vec = []
            lb_vec.append(list(-1*Pdc_max*np.ones(n)))
            lb_vec.append(np.zeros(n))
            lb_vec.append(np.zeros(n))
            lb_vec.append(Es_min*np.ones(n))
            lb_vec = list(itertools.chain(*lb_vec))
            lb_vec.append(0.0)                     
            
            
            # Upper bounds 
            # The maximum exchange with the grid is when there is the maximum demand and the
            # storage system is charging at maximum rate
            # The maximum charge and discharge power are specified in the previous section 

            ub_vec = []
            ub_vec.append(list(Psc_max*np.ones(n)+max_demand))
            ub_vec.append(Psc_max*np.ones(n))
            ub_vec.append(Pdc_max*np.ones(n))
            ub_vec.append(Es_max*np.ones(n))
            ub_vec = list(itertools.chain(*ub_vec))
            ub_vec.append(999)  
            
            bounds = []

            for i in range(len(lb_vec)): 
                bounds.append((lb_vec[i],ub_vec[i]))           

            res = linprog(f, A_eq=Aeq, b_eq=beq, bounds=bounds, options={"disp": True})
 
            original_cost_aux = original_cost
            
            pos_x = 0
            for c in range(d*num_work_hours,(d+1)*num_work_hours):
                Px[b][0][c] = res.x[pos_x]
                Pchar[b][0][c] = res.x[n+pos_x]
                Pdis[b][0][c] = res.x[2*n+pos_x]
                E[b][0][c]= res.x[3*n+pos_x]
                
                pos_x = pos_x+1

            Pdis_curr_iter = res.x[2*n:3*n]
            Pchar_curr_iter = res.x[n:2*n]

            #The original cost just need to be calculated once, 
            #so it is going to be calculated for the first vehicle
            
            if b == 0: 
                original_cost.append(sum(Pd*f1))

            #The reduction associated to the storage must be calculated for each
            #vehicle, as each one is considered as an independent storage
            savings[b][0][d]= [sum(Pdis_curr_iter*f1) - sum(Pchar_curr_iter*f1)] 

            
    ##Economic analysis

    aggregated_savings= np.zeros(int(len(data)/num_work_hours));

    for d in range(int(len(data)/num_work_hours)):
        agg_svg_day = 0
        for b in range(len(Initial_E_vec)):
            agg_svg_aux =  agg_svg_day
            agg_svg_day = agg_svg_aux + float(savings[b][0][d][0])

        aggregated_savings[d] = agg_svg_day

    total_original_cost = sum(original_cost)
    total_savings = sum(aggregated_savings)

    return aggregated_savings, original_cost

# %%
for n in num_vehicles: 
    for c in charger_power: 
        for e in energy_vehicle: 
            for ef in eff: 
                for i in avg_initial_energy: 
                    
                    [aggregated_savings, daily_original_cost] = daily_analysis(n, c, e, ef, i,data)
                    

results = pd.DataFrame(aggregated_savings, columns =['aggregated_savings']) 

results["daily_original_cost"] = daily_original_cost
# Out:
# Optimization terminated successfully.
#          Current function value: 31.808243
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.598448
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.655518
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.883808
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.849299
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.834990
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.524623
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.636409
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.959833
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.158714
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.860668
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.041089
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.568542
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.748181
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.727663
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.901561
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.822239
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.012182
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.850478
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.016885
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.849992
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.975612
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.798062
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.907401
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.653698
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.724949
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.976935
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.776583
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.109751
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.155467
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.885727
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.196394
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.815205
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.798686
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.108337
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.082104
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.138279
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.067811
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.865384
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.252292
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.151867
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.865857
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.921222
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.118451
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.929825
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.868621
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.050200
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.951070
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.924454
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.004227
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.042133
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.200236
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.262606
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.459121
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.287553
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 31.832826
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.219484
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.116513
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.433633
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.300962
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.370687
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.204258
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.185758
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.338895
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.286291
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.202687
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.379501
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.644812
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.118194
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.554011
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.444322
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.788673
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.508201
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.319008
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.289756
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.732133
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.476971
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.361048
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.387315
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.661900
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.495911
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.234541
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.533082
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.183734
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.304285
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.239048
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.523532
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.328610
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.731027
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.767780
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.291094
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.590771
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.648911
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.526827
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.620793
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.463487
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.428150
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.415048
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.913900
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.357278
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.696120
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.723113
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.590605
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.507868
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.643473
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.408878
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.772589
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.609210
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.295715
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.687207
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.653263
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.766281
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.671417
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.711683
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.681145
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.692287
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.693033
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 33.029642
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 33.010489
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.827841
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.796012
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.888465
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.922086
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.788513
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.772138
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.836437
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.992823
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.831575
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.701138
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 137.978418
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 32.806324
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.949441
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.920263
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.781192
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.712831
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.935502
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 32.981646
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 33.004241
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 33.103231
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 33.074132
#          Iterations: 74
# Optimization terminated successfully.
#          Current function value: 34.813805
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.064089
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 34.859975
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.140545
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.002292
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 34.947361
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 34.698220
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 43.343969
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 161.210524
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 162.422793
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 43.490932
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 43.720074
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 34.819434
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.178128
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 34.999334
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.360177
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.207785
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.032605
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.017327
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 35.263443
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 161.945710
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 162.126519
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 161.879807
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 43.630970
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 44.019251
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 162.171841
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 43.962545
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 44.226020
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 43.742435
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 35.017597
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 44.120806
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 163.244551
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 427.957031
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 979.493513
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 424.113457
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 427.309315
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 163.292111
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 163.625869
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 44.132014
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 43.837547
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 44.262086
#          Iterations: 67
# Optimization terminated successfully.
#          Current function value: 31.808243
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.598448
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.655518
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.883808
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.849299
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.834990
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.524623
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.636409
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.959833
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.158714
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.860668
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.041089
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.568542
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.748181
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.727663
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.901561
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.822239
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.012182
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.850478
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.016885
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.849992
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.975612
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.798062
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.907401
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.653698
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.724949
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.976935
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.776583
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.109751
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.155467
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.885727
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.196394
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.815205
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.798686
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.108337
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.082104
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.138279
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.067811
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.865384
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.252292
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.151867
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.865857
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.921222
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.118451
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.929825
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.868621
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.050200
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.951070
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.924454
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.004227
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.042133
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.200236
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.262606
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.459121
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.287553
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.832826
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.219484
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.116513
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.433633
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.300962
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.370687
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.204258
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.185758
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.338895
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.286291
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.202687
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.379501
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.644812
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.118194
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.554011
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.444322
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.788673
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.508201
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.319008
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.289756
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.732133
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.476971
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.361048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.387315
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.661900
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.495911
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.234541
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.533082
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.183734
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.304285
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.239048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.523532
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.328610
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.731027
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.767780
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.291094
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.590771
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.648911
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.526827
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.620793
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.463487
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.428150
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.415048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.913900
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.357278
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.696120
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.723113
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.590605
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.507868
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.643473
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.408878
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.772589
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.609210
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.295715
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.687207
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.653263
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.766281
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.671417
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.711683
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.681145
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.692287
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.693033
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.029642
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.010489
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.827841
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.796012
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.888465
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.922086
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.788513
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.772138
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.836437
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.992823
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.831575
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.701138
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 139.256684
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 32.806324
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.949441
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.920263
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.781192
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.712831
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.935502
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.981646
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.004241
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.103231
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.074132
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 34.878812
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.129096
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 34.924983
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.205553
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.067300
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.012369
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 34.763228
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 43.571367
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 164.187404
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 165.399673
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.718330
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.947472
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 34.884442
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.243136
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.064341
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.425184
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.272793
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.097612
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.082335
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 35.328450
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 164.922590
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 165.103399
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 164.856687
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.858368
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.246649
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 165.148721
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.189943
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.453418
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.969833
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.082604
#          Iterations: 70
# Optimization terminated successfully.
#          Current function value: 44.348204
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 166.221432
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 433.602515
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 994.566145
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 429.758941
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 432.954800
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 166.268991
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 166.602749
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.359412
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.064945
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.489484
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 31.808243
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.598448
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.655518
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.883808
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.849299
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.834990
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.524623
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.636409
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.959833
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.158714
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.860668
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.041089
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.568542
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.748181
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.727663
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.901561
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.822239
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.012182
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.850478
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.016885
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.849992
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.975612
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.798062
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.907401
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.653698
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.724949
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.976935
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.776583
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.109751
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.155467
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.885727
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.196394
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.815205
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.798686
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.108337
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.082104
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.138279
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.067811
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.865384
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.252292
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.151867
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.865857
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.921222
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.118451
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.929825
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.868621
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.050200
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.951070
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.924454
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.004227
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.042133
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.200236
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.262606
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.459121
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.287553
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.832826
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.219484
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.116513
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.433633
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.300962
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.370687
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.204258
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.185758
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.338895
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.286291
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.202687
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.379501
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.644812
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.118194
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.554011
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.444322
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.788673
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.508201
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.319008
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.289756
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.732133
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.476971
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.361048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.387315
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.661900
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.495911
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.234541
#          Iterations: 72
# Optimization terminated successfully.
# ...
# Optimization terminated successfully.
#          Current function value: 31.798686
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.108337
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.082104
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.138279
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.067811
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.865384
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.252292
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.151867
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.865857
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.921222
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.118451
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.929825
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.868621
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.050200
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.951070
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.924454
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.004227
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.042133
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.200236
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.262606
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.459121
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.287553
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 31.832826
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.219484
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.116513
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.433633
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.300962
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.370687
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.204258
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.185758
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.338895
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.286291
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.202687
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.379501
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.644812
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.118194
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.554011
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.444322
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.788673
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.508201
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.319008
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.289756
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.732133
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.476971
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.361048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.387315
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.661900
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.495911
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.234541
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.533082
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.183734
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.304285
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.239048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.523532
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.328610
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.731027
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.767780
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.291094
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.590771
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.648911
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.526827
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.620793
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.463487
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.428150
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.415048
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.913900
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.357278
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.696120
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.723113
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.590605
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.507868
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.643473
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.408878
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.772589
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.609210
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.295715
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.687207
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.653263
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.766281
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.671417
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.711683
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.681145
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.692287
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.693033
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.029642
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.010489
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.827841
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.796012
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.888465
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.922086
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.788513
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.772138
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.836437
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.992823
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.831575
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.701138
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 138.176260
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 32.806324
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.949441
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.920263
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.781192
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.712831
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.935502
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 32.981646
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.004241
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.103231
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 33.074132
#          Iterations: 72
# Optimization terminated successfully.
#          Current function value: 34.820970
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.071254
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 34.867141
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.147711
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.009458
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 34.954527
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 34.705386
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.377432
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 161.718955
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 162.931224
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 43.524395
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.753537
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 34.826600
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.185294
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.006499
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.367342
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.214951
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.039770
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.024493
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.270608
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 162.454141
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 162.634950
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 162.388238
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 43.664433
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.052714
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 162.680272
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 43.996008
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.259483
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.775898
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 35.024762
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.154268
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 163.752982
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 428.802783
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 981.692992
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 424.959209
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 428.155068
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 163.800542
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 164.134300
#          Iterations: 68
# Optimization terminated successfully.
#          Current function value: 44.165477
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 43.871010
#          Iterations: 69
# Optimization terminated successfully.
#          Current function value: 44.295549
#          Iterations: 69

# %%
results[140:180]
# Out:
#      aggregated_savings  daily_original_cost
# 140           31.132419            33.240479
# 141           31.132419            33.457350
# 142           31.132419            33.329071
# 143           31.132419            33.523440
# 144           31.132419            33.563406
# 145           31.132419            33.790447
# 146           31.132419            33.564778
# 147           74.342528            40.183035
# 148          677.554314           127.625297
# 149          677.554314           129.647112
# 150           74.342528            40.189558
# 151           74.342528            40.275556
# 152           31.132419            33.384938
# 153           31.132419            33.606886
# 154           31.132419            33.202408
# 155           31.132419            33.367468
# 156           31.132419            33.588386
# 157           31.132419            33.318990
# 158           31.132419            33.510659
# 159           31.132419            33.779870
# 160          677.554314           129.432310
# 161          677.554314           130.947474
# 162          677.554314           130.250095
# 163           74.342528            40.188420
# 164           74.342528            40.301599
# 165          677.554314           129.779049
# 166           74.342528            40.593752
# 167           74.342528            40.151319
# 168           74.342528            40.176761
# 169           31.132419            33.740041
# 170           74.342528            40.530766
# 171          677.554314           130.672289
# 172         1722.486240           360.940296
# 173         4280.834805           775.391851
# 174         1722.486240           358.484268
# 175         1722.486240           360.402539
# 176          677.554314           130.681772
# 177          677.554314           130.303658
# 178           74.342528            40.623511
# 179           74.342528            40.453393

# %%
results.to_pickle("./results_winter_summer_97.pkl")

# %%
def hourly_analysis(num_vehicles, charger_power, energy_vehicle, eff, avg_initial_energy,data):
    
    
    ##Storage specifications

    #Power of storage charge/discharge
    Psc_max = charger_power #MW
    Pdc_max = charger_power #MW

    #Maximum/minimum avaliable energy in the storage system
    Es_max = energy_vehicle #MW
    Es_min = 0.25*energy_vehicle #MW

    #Initial storage
    Initial_battery_vec = np.random.normal(avg_initial_energy,0.1,num_vehicles) 
    
    Initial_E_vec = Initial_battery_vec*energy_vehicle #MWh
       
    ##Optimization

    max_demand = 100/1000 #Max demand is assumed to be 0.1 MW (medium business)
    
    #Arrays for the results
    
    Px = ThreeD(len(data), 1, num_vehicles)
    Pchar = ThreeD(len(data), 1, num_vehicles)
    Pdis = ThreeD(len(data), 1, num_vehicles)
    E= ThreeD(len(data), 1, num_vehicles)
    original_cost = [ ];
    savings = ThreeD(int(len(data)), 1, num_vehicles) 
   

    # For this day (which has 10 labor hours)
    # For each vehicle
    
    for b in range(len(Initial_E_vec)): 
            
        Pd = data['Hourly Load'] #Demand vector in MWh
        
        n = len(Pd)  #Number of hours

        # vector x: Px(1 - n) | Pchar(n+1 - 2n) | Pdis(2n+1 - 3n) | Energy(3n+1 - 4n) | E0(4n+1)|
        # Where:
        #   - Px is the exchange with the grid 
        #   - Pchar is the Energy Storage charge
        #   - Pdis is the Energy Storage discharge

        f1 = data['Hourly Price'] #prices in $/MWh (original in $/kWh)

        f23 = list(np.zeros(2*n))
        f4 = list(np.zeros(n))

        f = []  #cost vector

        f.append(f1)
        f.append(f23)
        f.append(f4)

        f = list(itertools.chain(*f)) #flatten the vector 
        f.append(0.0)

        # Building Aeq Matrix
        # n rows for power balances equations 
        # n rows for energy balances equations
        # 2 rows for setting the initial energy in the storage and final energy
        # equal to initial 

        Aeq = np.zeros((2*n+2,4*n+1))
        #indices for submatrices
        sP = 0
        sC = n
        sD = 2*n
        sE = 3*n 

        for i in range(n): 
            Aeq[i,i]=1
            Aeq[i,i+sC]=-1
            Aeq[i,i+sD]=1

            r = n+i
            Aeq[r,i+sC]=-eff
            Aeq[r,i+sD]=1/eff
            Aeq[r,i+sE]=1
            Aeq[r,i+sE-1]=-1


        Aeq[n,sE-1]=0
        Aeq[n,4*n]=-1
        Aeq[2*n,4*n]=1
        Aeq[2*n+1,4*n-1]=1
        Aeq[2*n+1,4*n]=-1


        #Building Beq Matrix

        beq = []

        beq.append(list(Pd))
        beq.append(list(np.zeros(n+2)))

        beq = list(itertools.chain(*beq)) #flatten the vector 

        beq[2*n] = Initial_E_vec[b-1]


        # Lower bounds 
        # The minimum exchange with the grid is when there is no demand and the
        # storage system is discharging at maximum rate
        # The minimum charge and discharge power is zero 

        lb_vec = []
        lb_vec.append(list(-1*Pdc_max*np.ones(n)))
        lb_vec.append(np.zeros(n))
        lb_vec.append(np.zeros(n))
        lb_vec.append(Es_min*np.ones(n))
        lb_vec = list(itertools.chain(*lb_vec))
        lb_vec.append(0.0)                     


        # Upper bounds 
        # The maximum exchange with the grid is when there is the maximum demand and the
        # storage system is charging at maximum rate
        # The maximum charge and discharge power are specified in the previous section 

        ub_vec = []
        ub_vec.append(list(Psc_max*np.ones(n)+max_demand))
        ub_vec.append(Psc_max*np.ones(n))
        ub_vec.append(Pdc_max*np.ones(n))
        ub_vec.append(Es_max*np.ones(n))
        ub_vec = list(itertools.chain(*ub_vec))
        ub_vec.append(999)  

        bounds = []

        for i in range(len(lb_vec)): 
            bounds.append((lb_vec[i],ub_vec[i]))           

        res = linprog(f, A_eq=Aeq, b_eq=beq, bounds=bounds, options={"disp": True})
        
        print(res)

        original_cost_aux = original_cost

        pos_x = 0
        for c in range(0,num_work_hours):
            Px[b][0][c] = res.x[pos_x]
            Pchar[b][0][c] = res.x[n+pos_x]
            Pdis[b][0][c] = res.x[2*n+pos_x]
            E[b][0][c]= res.x[3*n+pos_x]

            pos_x = pos_x+1

        Pdis_curr_iter = res.x[2*n:3*n]
        Pchar_curr_iter = res.x[n:2*n]

        #The original cost just need to be calculated once, 
        #so it is going to be calculated for the first vehicle

        if b == 0: 
            original_cost.append(Pd*f1)

        #The reduction associated to the storage must be calculated for each
        #vehicle, as each one is considered as an independent storage
        savings[b][0][0] = [Pdis_curr_iter*f1 - Pchar_curr_iter*f1] 
        
            
    ##Economic analysis

    aggregated_savings_list = []
    aggregated_savings = np.zeros(n)

    for b in range(len(Initial_E_vec)):
        agg_svg_aux =  aggregated_savings
        aggregated_savings  = np.add(agg_svg_aux,savings[b][0][0])

    aggregated_savings_list.append(aggregated_savings)
    total_original_cost = sum(original_cost)
    total_savings = sum(aggregated_savings)

    return aggregated_savings_list, original_cost

# %%
data_day_high_price = data[0:num_work_hours]
data_day_high_price.reset_index(drop=True)
# Out:
#    Unnamed: 0                 Date  Hourly Price  Hourly Load
# 0           0  2018-02-02 09:00:00       0.05793    35.193771
# 1           1  2018-02-02 10:00:00       0.05805    37.828085
# 2           2  2018-02-02 11:00:00       0.05959    63.040090
# 3           3  2018-02-02 12:00:00       0.06158    77.137543
# 4           4  2018-02-02 13:00:00       0.06061    80.476139
# 5           5  2018-02-02 14:00:00       0.06065    81.116858
# 6           6  2018-02-02 15:00:00       0.05997    76.693564
# 7           7  2018-02-02 16:00:00       0.05986    74.446259

# %%
### Hourly analysis for the day , where prices are extremely high (and the savings as well)

for n in num_vehicles: 
    for c in charger_power: 
        for e in energy_vehicle: 
            for ef in eff: 
                for i in avg_initial_energy: 
                    
                    [aggregated_savings, daily_original_cost] = hourly_analysis(n, c, e, ef, i,data_day_high_price)
# Out:
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00, -6.93889390e-18,
#        -6.93889390e-18,  0.00000000e+00, -1.38777878e-17,  1.38777878e-17,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.82145965e-17, 0.00000000e+00, 0.00000000e+00,
#        4.18220419e-02, 4.18220419e-02, 4.18220419e-02, 4.18220419e-02,
#        4.18220419e-02, 4.18220419e-02, 4.18220419e-02, 4.18220419e-02,
#        4.18220419e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00, -6.93889390e-18,
#         6.93889390e-18, -1.38777878e-17,  6.93889390e-18,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.04083409e-17, 0.00000000e+00, 0.00000000e+00,
#        3.91893999e-02, 3.91893999e-02, 3.91893999e-02, 3.91893999e-02,
#        3.91893999e-02, 3.91893999e-02, 3.91893999e-02, 3.91893999e-02,
#        3.91893999e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         6.93889390e-18,  0.00000000e+00, -2.08166817e-17, -6.93889390e-18,
#         1.38777878e-17, -6.93889390e-18, -6.93889390e-18,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.64798730e-17, 0.00000000e+00, 0.00000000e+00,
#        4.32343644e-02, 4.32343644e-02, 4.32343644e-02, 4.32343644e-02,
#        4.32343644e-02, 4.32343644e-02, 4.32343644e-02, 4.32343644e-02,
#        4.32343644e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 56
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00,  0.00000000e+00, -2.08166817e-17,  0.00000000e+00,
#         0.00000000e+00, -6.93889390e-18,  6.93889390e-18,  6.93889390e-18,
#         0.00000000e+00,  6.93889390e-18])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 56
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.90819582e-17, 0.00000000e+00, 0.00000000e+00,
#        3.36631695e-02, 3.36631695e-02, 3.36631695e-02, 3.36631695e-02,
#        3.36631695e-02, 3.36631695e-02, 3.36631695e-02, 3.36631695e-02,
#        3.36631695e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 56
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -3.46944695e-18,  6.93889390e-18,  0.00000000e+00, -6.93889390e-18,
#         3.46944695e-18, -3.46944695e-18, -3.46944695e-18, -1.38777878e-17,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 56
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.16840434e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.02715423e-02, 3.02715423e-02, 3.02715423e-02, 3.02715423e-02,
#        3.02715423e-02, 3.02715423e-02, 3.02715423e-02, 3.02715423e-02,
#        3.02715423e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -1.38777878e-17,  1.38777878e-17, -6.93889390e-18,
#        -6.93889390e-18,  0.00000000e+00, -6.93889390e-18,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.99493200e-17, 0.00000000e+00, 0.00000000e+00,
#        4.79841947e-02, 4.79841947e-02, 4.79841947e-02, 4.79841947e-02,
#        4.79841947e-02, 4.79841947e-02, 4.79841947e-02, 4.79841947e-02,
#        4.79841947e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 56
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -1.38777878e-17,  0.00000000e+00,  6.93889390e-18,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 56
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.21430643e-17,
#        5.69834153e-02, 5.69834153e-02, 5.69834153e-02, 5.69834153e-02,
#        5.69834153e-02, 5.69834153e-02, 5.69834153e-02, 5.69834153e-02,
#        5.69834153e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -2.08166817e-17,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -6.93889390e-18,  1.38777878e-17, -6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.90819582e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.01738893e-02, 4.01738893e-02, 4.01738893e-02, 4.01738893e-02,
#        4.01738893e-02, 4.01738893e-02, 4.01738893e-02, 4.01738893e-02,
#        4.01738893e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -1.38777878e-17,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.73472348e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.80890810e-02, 3.80890810e-02, 3.80890810e-02, 3.80890810e-02,
#        3.80890810e-02, 3.80890810e-02, 3.80890810e-02, 3.80890810e-02,
#        3.80890810e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18, -6.93889390e-18, -1.38777878e-17,
#         6.93889390e-18,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.25514052e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.08450891e-02, 4.08450891e-02, 4.08450891e-02, 4.08450891e-02,
#        4.08450891e-02, 4.08450891e-02, 4.08450891e-02, 4.08450891e-02,
#        4.08450891e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00, -1.38777878e-17,
#         0.00000000e+00,  1.38777878e-17, -1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.99493200e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.10615993e-02, 4.10615993e-02, 4.10615993e-02, 4.10615993e-02,
#        4.10615993e-02, 4.10615993e-02, 4.10615993e-02, 4.10615993e-02,
#        4.10615993e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 56
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00,  0.00000000e+00, -1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00, -1.38777878e-17,  6.93889390e-18,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 56
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.90819582e-17, 0.00000000e+00, 0.00000000e+00,
#        3.32299857e-02, 3.32299857e-02, 3.32299857e-02, 3.32299857e-02,
#        3.32299857e-02, 3.32299857e-02, 3.32299857e-02, 3.32299857e-02,
#        3.32299857e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18,  6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#        -1.38777878e-17,  6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.20417043e-18, 0.00000000e+00, 0.00000000e+00,
#        4.64318883e-02, 4.64318883e-02, 4.64318883e-02, 4.64318883e-02,
#        4.64318883e-02, 4.64318883e-02, 4.64318883e-02, 4.64318883e-02,
#        4.64318883e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         6.93889390e-18,  0.00000000e+00, -2.08166817e-17, -1.38777878e-17,
#         6.93889390e-18, -6.93889390e-18,  1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.64798730e-17, 0.00000000e+00, 0.00000000e+00,
#        4.33154678e-02, 4.33154678e-02, 4.33154678e-02, 4.33154678e-02,
#        4.33154678e-02, 4.33154678e-02, 4.33154678e-02, 4.33154678e-02,
#        4.33154678e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,  6.93889390e-18,
#        -6.93889390e-18, -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.21430643e-17, 0.00000000e+00, 0.00000000e+00,
#        4.75945958e-02, 4.75945958e-02, 4.75945958e-02, 4.75945958e-02,
#        4.75945958e-02, 4.75945958e-02, 4.75945958e-02, 4.75945958e-02,
#        4.75945958e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18,  0.00000000e+00, -1.38777878e-17,  6.93889390e-18,
#        -1.38777878e-17,  0.00000000e+00,  1.38777878e-17, -6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.90819582e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.66118199e-02, 3.66118199e-02, 3.66118199e-02, 3.66118199e-02,
#        3.66118199e-02, 3.66118199e-02, 3.66118199e-02, 3.66118199e-02,
#        3.66118199e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18, -6.93889390e-18,  0.00000000e+00,
#         6.93889390e-18, -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.04083409e-17, 0.00000000e+00, 0.00000000e+00,
#        3.94852525e-02, 3.94852525e-02, 3.94852525e-02, 3.94852525e-02,
#        3.94852525e-02, 3.94852525e-02, 3.94852525e-02, 3.94852525e-02,
#        3.94852525e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18,  0.00000000e+00, -6.93889390e-18,  0.00000000e+00,
#         0.00000000e+00, -1.38777878e-17,  0.00000000e+00,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.73472348e-17, 0.00000000e+00, 0.00000000e+00,
#        4.45715140e-02, 4.45715140e-02, 4.45715140e-02, 4.45715140e-02,
#        4.45715140e-02, 4.45715140e-02, 4.45715140e-02, 4.45715140e-02,
#        4.45715140e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         6.93889390e-18, -1.38777878e-17, -6.93889390e-18,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00, -1.38777878e-17,  1.38777878e-17,
#         0.00000000e+00,  6.93889390e-18])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.38777878e-17, 0.00000000e+00,
#        4.60568225e-02, 4.60568225e-02, 4.60568225e-02, 4.60568225e-02,
#        4.60568225e-02, 4.60568225e-02, 4.60568225e-02, 4.60568225e-02,
#        4.60568225e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         6.93889390e-18, -2.08166817e-17,  1.38777878e-17, -6.93889390e-18,
#        -6.93889390e-18,  6.93889390e-18, -1.38777878e-17,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.38777878e-17, 0.00000000e+00, 0.00000000e+00,
#        4.69760418e-02, 4.69760418e-02, 4.69760418e-02, 4.69760418e-02,
#        4.69760418e-02, 4.69760418e-02, 4.69760418e-02, 4.69760418e-02,
#        4.69760418e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.38777878e-17, -1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 6.07153217e-18, 0.00000000e+00,
#        5.31398346e-02, 5.31398346e-02, 5.31398346e-02, 5.31398346e-02,
#        5.31398346e-02, 5.31398346e-02, 5.31398346e-02, 5.31398346e-02,
#        5.31398346e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -6.93889390e-18,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.30104261e-17, 0.00000000e+00, 0.00000000e+00,
#        4.71208197e-02, 4.71208197e-02, 4.71208197e-02, 4.71208197e-02,
#        4.71208197e-02, 4.71208197e-02, 4.71208197e-02, 4.71208197e-02,
#        4.71208197e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -1.38777878e-17,  6.93889390e-18,  0.00000000e+00,
#        -6.93889390e-18,  6.93889390e-18, -1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.08166817e-17, 0.00000000e+00,
#        4.89141794e-02, 4.89141794e-02, 4.89141794e-02, 4.89141794e-02,
#        4.89141794e-02, 4.89141794e-02, 4.89141794e-02, 4.89141794e-02,
#        4.89141794e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -1.38777878e-17,  6.93889390e-18,  0.00000000e+00,  6.93889390e-18,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00,  6.93889390e-18,
#         0.00000000e+00,  6.93889390e-18])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 9.54097912e-18, 0.00000000e+00,
#        5.50444542e-02, 5.50444542e-02, 5.50444542e-02, 5.50444542e-02,
#        5.50444542e-02, 5.50444542e-02, 5.50444542e-02, 5.50444542e-02,
#        5.50444542e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18, -6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.47451495e-17, 0.00000000e+00,
#        4.99420445e-02, 4.99420445e-02, 4.99420445e-02, 4.99420445e-02,
#        4.99420445e-02, 4.99420445e-02, 4.99420445e-02, 4.99420445e-02,
#        4.99420445e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18, -6.93889390e-18, -6.93889390e-18,
#         6.93889390e-18, -2.77555756e-17,  1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00, -6.93889390e-18])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.90819582e-17, 0.00000000e+00, 0.00000000e+00,
#        4.28199139e-02, 4.28199139e-02, 4.28199139e-02, 4.28199139e-02,
#        4.28199139e-02, 4.28199139e-02, 4.28199139e-02, 4.28199139e-02,
#        4.28199139e-02])
# ...
#         0.00000000e+00, -6.93889390e-18,  6.93889390e-18, -1.38777878e-17,
#         0.00000000e+00,  0.00000000e+00, -6.93889390e-18,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.64798730e-17, 0.00000000e+00,
#        4.89361522e-02, 4.89361522e-02, 4.89361522e-02, 4.89361522e-02,
#        4.89361522e-02, 4.89361522e-02, 4.89361522e-02, 4.89361522e-02,
#        4.89361522e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00, -1.38777878e-17,
#        -6.93889390e-18, -6.93889390e-18,  6.93889390e-18,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.99493200e-17, 0.00000000e+00, 0.00000000e+00,
#        4.18638252e-02, 4.18638252e-02, 4.18638252e-02, 4.18638252e-02,
#        4.18638252e-02, 4.18638252e-02, 4.18638252e-02, 4.18638252e-02,
#        4.18638252e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 54
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -6.93889390e-18,  0.00000000e+00,  2.08166817e-17,  0.00000000e+00,
#         0.00000000e+00, -1.38777878e-17,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 54
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.73472348e-18, 0.00000000e+00, 0.00000000e+00,
#        4.64033900e-02, 4.64033900e-02, 4.64033900e-02, 4.64033900e-02,
#        4.64033900e-02, 4.64033900e-02, 4.64033900e-02, 4.64033900e-02,
#        4.64033900e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00, -1.38777878e-17,
#         0.00000000e+00,  1.38777878e-17, -1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.99493200e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.05317845e-02, 4.05317845e-02, 4.05317845e-02, 4.05317845e-02,
#        4.05317845e-02, 4.05317845e-02, 4.05317845e-02, 4.05317845e-02,
#        4.05317845e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18, -6.93889390e-18, -6.93889390e-18,
#         6.93889390e-18, -1.38777878e-17,  0.00000000e+00,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.99493200e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.09108597e-02, 4.09108597e-02, 4.09108597e-02, 4.09108597e-02,
#        4.09108597e-02, 4.09108597e-02, 4.09108597e-02, 4.09108597e-02,
#        4.09108597e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#        -1.38777878e-17,  6.93889390e-18,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -6.93889390e-18,  0.00000000e+00,  6.93889390e-18,
#         0.00000000e+00,  6.93889390e-18])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.12757026e-17, 0.00000000e+00,
#        5.53361667e-02, 5.53361667e-02, 5.53361667e-02, 5.53361667e-02,
#        5.53361667e-02, 5.53361667e-02, 5.53361667e-02, 5.53361667e-02,
#        5.53361667e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -2.08166817e-17,  0.00000000e+00,  0.00000000e+00,
#        -6.93889390e-18,  0.00000000e+00,  6.93889390e-18,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.0720000e-01, 1.0720000e-01, 1.0720000e-01, 1.0720000e-01,
#        1.0720000e-01, 1.0720000e-01, 1.0720000e-01, 1.0720000e-01,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.9949320e-17, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        3.9754466e-02, 3.9754466e-02, 3.9754466e-02, 3.9754466e-02,
#        3.9754466e-02, 3.9754466e-02, 3.9754466e-02, 3.9754466e-02,
#        3.9754466e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00, -6.93889390e-18,  6.93889390e-18, -1.38777878e-17,
#         0.00000000e+00, -6.93889390e-18,  6.93889390e-18, -6.93889390e-18,
#         0.00000000e+00, -6.93889390e-18])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.56125113e-17, 0.00000000e+00,
#        4.98293942e-02, 4.98293942e-02, 4.98293942e-02, 4.98293942e-02,
#        4.98293942e-02, 4.98293942e-02, 4.98293942e-02, 4.98293942e-02,
#        4.98293942e-02])
# Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible.
#          Iterations: 55
#      con: array([ 3.50865714e+01,  3.77208849e+01,  6.29328903e+01,  7.70303431e+01,
#         8.03689385e+01,  8.10096579e+01,  7.65863640e+01,  7.43390591e+01,
#         0.00000000e+00,  6.93889390e-18, -1.38777878e-17,  0.00000000e+00,
#         0.00000000e+00,  6.93889390e-18, -1.38777878e-17,  6.93889390e-18,
#         0.00000000e+00,  0.00000000e+00])
#      fun: 0.051267328
#  message: "Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 5.3e+02 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 5.3e+02. If this tolerance is unacceptably  large the problem may be infeasible."
#      nit: 55
#    slack: array([], dtype=float64)
#   status: 2
#  success: False
#        x: array([1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        1.07200000e-01, 1.07200000e-01, 1.07200000e-01, 1.07200000e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.33680869e-18, 0.00000000e+00,
#        5.38684335e-02, 5.38684335e-02, 5.38684335e-02, 5.38684335e-02,
#        5.38684335e-02, 5.38684335e-02, 5.38684335e-02, 5.38684335e-02,
#        5.38684335e-02])

# %%
aggregated_savings
# Out:
# [array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          2.39722825e-17, 4.57141703e-17, 2.10143361e-17, 1.86912985e-18]])]

# %%
daily_original_cost
# Out:
# [0    2.038775
#  1    2.195920
#  2    3.756559
#  3    4.750130
#  4    4.877659
#  5    4.919737
#  6    4.599313
#  7    4.456353
#  dtype: float64]

# %%
lista = [2,2,2,2]
np.add(lista,np.zeros(4))
# Out:
# array([2., 2., 2., 2.])
